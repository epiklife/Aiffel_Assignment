# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.2, random_state=42)
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 45s 0us/step
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.style.use('seaborn-white')

plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15480\2984074990.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %%
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
x_train = x_train.reshape(-1, 32 * 32 * 3)
x_val = x_val.reshape(-1, 32 * 32 * 3)
x_test = x_test.reshape(-1, 32 * 32 * 3)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(3072,)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               786688
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 822,410
# Trainable params: 821,642
# Non-trainable params: 768
# _________________________________________________________________

# %%
utils.plot_model(model, show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 utils.plot_model(model, show_shapes=True)
#
# NameError: name 'utils' is not defined

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss', mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_val, y_val),
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/50
# 625/625 [==============================] - ETA: 0s - loss: 2.2205 - accuracy: 0.2610
# Epoch 1: val_loss improved from inf to 2.00293, saving model to best_model.h5
# 625/625 [==============================] - 12s 16ms/step - loss: 2.2205 - accuracy: 0.2610 - val_loss: 2.0029 - val_accuracy: 0.2954
# Epoch 2/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.8830 - accuracy: 0.3254
# Epoch 2: val_loss improved from 2.00293 to 1.82407, saving model to best_model.h5
# 625/625 [==============================] - 9s 14ms/step - loss: 1.8827 - accuracy: 0.3255 - val_loss: 1.8241 - val_accuracy: 0.3485
# Epoch 3/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.8413 - accuracy: 0.3402
# Epoch 3: val_loss improved from 1.82407 to 1.75701, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.8417 - accuracy: 0.3399 - val_loss: 1.7570 - val_accuracy: 0.3718
# Epoch 4/50
# 621/625 [============================>.] - ETA: 0s - loss: 1.8404 - accuracy: 0.3410
# Epoch 4: val_loss improved from 1.75701 to 1.74815, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.8400 - accuracy: 0.3411 - val_loss: 1.7482 - val_accuracy: 0.3642
# Epoch 5/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.8280 - accuracy: 0.3433
# Epoch 5: val_loss did not improve from 1.74815
# 625/625 [==============================] - 7s 11ms/step - loss: 1.8280 - accuracy: 0.3433 - val_loss: 1.7693 - val_accuracy: 0.3643
# Epoch 6/50
# 625/625 [==============================] - ETA: 0s - loss: 1.8075 - accuracy: 0.3582
# Epoch 6: val_loss did not improve from 1.74815
# 625/625 [==============================] - 7s 11ms/step - loss: 1.8075 - accuracy: 0.3582 - val_loss: 1.7569 - val_accuracy: 0.3574
# Epoch 7/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.8022 - accuracy: 0.3551
# Epoch 7: val_loss improved from 1.74815 to 1.67032, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.8019 - accuracy: 0.3553 - val_loss: 1.6703 - val_accuracy: 0.3988
# Epoch 8/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7959 - accuracy: 0.3568
# Epoch 8: val_loss did not improve from 1.67032
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7960 - accuracy: 0.3568 - val_loss: 1.6906 - val_accuracy: 0.3972
# Epoch 9/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7942 - accuracy: 0.3583
# Epoch 9: val_loss did not improve from 1.67032
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7941 - accuracy: 0.3584 - val_loss: 1.6969 - val_accuracy: 0.3950
# Epoch 10/50
# 623/625 [============================>.] - ETA: 0s - loss: 1.7922 - accuracy: 0.3609
# Epoch 10: val_loss did not improve from 1.67032
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7924 - accuracy: 0.3611 - val_loss: 2.5464 - val_accuracy: 0.3385
# Epoch 11/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7900 - accuracy: 0.3586
# Epoch 11: val_loss did not improve from 1.67032
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7900 - accuracy: 0.3586 - val_loss: 1.6897 - val_accuracy: 0.3895
# Epoch 12/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7889 - accuracy: 0.3595
# Epoch 12: val_loss improved from 1.67032 to 1.65610, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7889 - accuracy: 0.3595 - val_loss: 1.6561 - val_accuracy: 0.4130
# Epoch 13/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7953 - accuracy: 0.3565
# Epoch 13: val_loss improved from 1.65610 to 1.65401, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7951 - accuracy: 0.3568 - val_loss: 1.6540 - val_accuracy: 0.4162
# Epoch 14/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.7959 - accuracy: 0.3546
# Epoch 14: val_loss did not improve from 1.65401
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7960 - accuracy: 0.3546 - val_loss: 1.6686 - val_accuracy: 0.4093
# Epoch 15/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7865 - accuracy: 0.3607
# Epoch 15: val_loss improved from 1.65401 to 1.64346, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7865 - accuracy: 0.3606 - val_loss: 1.6435 - val_accuracy: 0.4117
# Epoch 16/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.7810 - accuracy: 0.3612
# Epoch 16: val_loss did not improve from 1.64346
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7808 - accuracy: 0.3612 - val_loss: 1.7039 - val_accuracy: 0.3845
# Epoch 17/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7734 - accuracy: 0.3639
# Epoch 17: val_loss improved from 1.64346 to 1.62950, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7732 - accuracy: 0.3640 - val_loss: 1.6295 - val_accuracy: 0.4198
# Epoch 18/50
# 623/625 [============================>.] - ETA: 0s - loss: 1.7589 - accuracy: 0.3697
# Epoch 18: val_loss did not improve from 1.62950
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7594 - accuracy: 0.3695 - val_loss: 1.6568 - val_accuracy: 0.3990
# Epoch 19/50
# 620/625 [============================>.] - ETA: 0s - loss: 1.7533 - accuracy: 0.3742
# Epoch 19: val_loss did not improve from 1.62950
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7531 - accuracy: 0.3743 - val_loss: 1.6398 - val_accuracy: 0.4001
# Epoch 20/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7484 - accuracy: 0.3731
# Epoch 20: val_loss did not improve from 1.62950
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7484 - accuracy: 0.3731 - val_loss: 1.6351 - val_accuracy: 0.4141
# Epoch 21/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.7412 - accuracy: 0.3772
# Epoch 21: val_loss did not improve from 1.62950
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7410 - accuracy: 0.3775 - val_loss: 1.6700 - val_accuracy: 0.4027
# Epoch 22/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7354 - accuracy: 0.3817
# Epoch 22: val_loss improved from 1.62950 to 1.62092, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7355 - accuracy: 0.3817 - val_loss: 1.6209 - val_accuracy: 0.4266
# Epoch 23/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7298 - accuracy: 0.3837
# Epoch 23: val_loss improved from 1.62092 to 1.61400, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7297 - accuracy: 0.3837 - val_loss: 1.6140 - val_accuracy: 0.4225
# Epoch 24/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.7264 - accuracy: 0.3824
# Epoch 24: val_loss improved from 1.61400 to 1.60889, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7263 - accuracy: 0.3824 - val_loss: 1.6089 - val_accuracy: 0.4225
# Epoch 25/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.7325 - accuracy: 0.3796
# Epoch 25: val_loss improved from 1.60889 to 1.59210, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7325 - accuracy: 0.3797 - val_loss: 1.5921 - val_accuracy: 0.4366
# Epoch 26/50
# 621/625 [============================>.] - ETA: 0s - loss: 1.7249 - accuracy: 0.3834
# Epoch 26: val_loss did not improve from 1.59210
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7244 - accuracy: 0.3837 - val_loss: 1.6246 - val_accuracy: 0.4186
# Epoch 27/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7303 - accuracy: 0.3830
# Epoch 27: val_loss did not improve from 1.59210
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7303 - accuracy: 0.3830 - val_loss: 1.6679 - val_accuracy: 0.3987
# Epoch 28/50
# 623/625 [============================>.] - ETA: 0s - loss: 1.7221 - accuracy: 0.3829
# Epoch 28: val_loss did not improve from 1.59210
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7221 - accuracy: 0.3829 - val_loss: 1.6381 - val_accuracy: 0.4117
# Epoch 29/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7216 - accuracy: 0.3839
# Epoch 29: val_loss did not improve from 1.59210
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7216 - accuracy: 0.3839 - val_loss: 1.6014 - val_accuracy: 0.4253
# Epoch 30/50
# 623/625 [============================>.] - ETA: 0s - loss: 1.7179 - accuracy: 0.3861
# Epoch 30: val_loss improved from 1.59210 to 1.59106, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7181 - accuracy: 0.3860 - val_loss: 1.5911 - val_accuracy: 0.4298
# Epoch 31/50
# 621/625 [============================>.] - ETA: 0s - loss: 1.7147 - accuracy: 0.3877
# Epoch 31: val_loss did not improve from 1.59106
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7146 - accuracy: 0.3876 - val_loss: 1.6519 - val_accuracy: 0.4034
# Epoch 32/50
# 623/625 [============================>.] - ETA: 0s - loss: 1.7102 - accuracy: 0.3891
# Epoch 32: val_loss did not improve from 1.59106
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7100 - accuracy: 0.3893 - val_loss: 1.6181 - val_accuracy: 0.4104
# Epoch 33/50
# 623/625 [============================>.] - ETA: 0s - loss: 1.7067 - accuracy: 0.3919
# Epoch 33: val_loss did not improve from 1.59106
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7071 - accuracy: 0.3917 - val_loss: 1.5914 - val_accuracy: 0.4384
# Epoch 34/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7084 - accuracy: 0.3891
# Epoch 34: val_loss improved from 1.59106 to 1.58303, saving model to best_model.h5
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7084 - accuracy: 0.3891 - val_loss: 1.5830 - val_accuracy: 0.4389
# Epoch 35/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.7095 - accuracy: 0.3904
# Epoch 35: val_loss did not improve from 1.58303
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7097 - accuracy: 0.3902 - val_loss: 1.5986 - val_accuracy: 0.4328
# Epoch 36/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7085 - accuracy: 0.3931
# Epoch 36: val_loss did not improve from 1.58303
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7085 - accuracy: 0.3931 - val_loss: 1.5944 - val_accuracy: 0.4293
# Epoch 37/50
# 622/625 [============================>.] - ETA: 0s - loss: 1.7042 - accuracy: 0.3956
# Epoch 37: val_loss did not improve from 1.58303
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7044 - accuracy: 0.3956 - val_loss: 1.6433 - val_accuracy: 0.4073
# Epoch 38/50
# 624/625 [============================>.] - ETA: 0s - loss: 1.7127 - accuracy: 0.3904
# Epoch 38: val_loss did not improve from 1.58303
# 625/625 [==============================] - 7s 11ms/step - loss: 1.7128 - accuracy: 0.3903 - val_loss: 1.6256 - val_accuracy: 0.4269
# Epoch 39/50
# 625/625 [==============================] - ETA: 0s - loss: 1.7153 - accuracy: 0.3870
# Epoch 39: val_loss did not improve from 1.58303
# 625/625 [==============================] - 7s 12ms/step - loss: 1.7153 - accuracy: 0.3870 - val_loss: 1.6055 - val_accuracy: 0.4302
# Epoch 39: early stopping

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.
import matplotlib.pyplot as plt

# 문제 3-5: 학습 히스토리 시각화
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Loss 그래프
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Accuracy 그래프
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# 학습 히스토리 시각화 함수 호출
plot_history(history)

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5979 - accuracy: 0.4282
# [1.5979140996932983, 0.42820000648498535]
